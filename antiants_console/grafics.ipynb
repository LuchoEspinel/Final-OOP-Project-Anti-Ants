# %%
import pandas as pd
import matplotlib as mpl

def graficas ():
    datos = pd.read_csv('yordi.csv', header = 0)
    df = pd.DataFrame(datos)
    df.groupby('Categoria')['Valor'].sum().plot(kind = 'bar')

graficas()
